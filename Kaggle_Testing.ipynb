# %% [markdown]
# <a href="https://colab.research.google.com/github/yunmokoo/Kaggle_Testing/blob/main/Kaggle_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic = pd.read_csv("train.csv")

# %%
category = ['Sex', 'Embarked']

fig, ax = plt.subplots(1,2, figsize = (12, 6))

for i, (column,axes) in list(enumerate(list(zip(category, ax.flatten())))):
  sns.countplot(ax = axes, x = titanic[column], hue = titanic['Pclass'], palette = 'magma', alpha = 0.8)
else:
  [axes.set_visible(True) for axes in ax.flatten()[i + 1:]]
plt.tight_layout()
plt.show()

# %%
print(category)


print(list((enumerate(zip(category, ax.flatten())))))
# Out:
# ['Sex', 'Embarked']
# [(0, ('Sex', <Axes: xlabel='Sex', ylabel='count'>)), (1, ('Embarked', <Axes: xlabel='Embarked', ylabel='count'>))]

# %%
df = pd.DataFrame(titanic)


numeric_values = df['Ticket'].str.extract(r'(\d+\.\d+|\d+)')

df['Ticket'] = pd.to_numeric(numeric_values[0], errors='coerce')

valuecount = df['Ticket'].value_counts()
print(valuecount)


df
# Out:
# 5.0         21
# 2.0         20
# 4.0          8
# 347082.0     7
# 1601.0       7
#             ..
# 349243.0     1
# 250651.0     1
# 226593.0     1
# 9234.0       1
# 370376.0     1
# Name: Ticket, Length: 635, dtype: int64
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df_count = pd.DataFrame(valuecount)
df_count

filt = (df_count['Ticket'] > 4)
df_count[filt]
# Out:
#            Ticket
# 5.0            21
# 2.0            20
# 4.0             8
# 347082.0        7
# 1601.0          7
# 2343.0          7
# 2144.0          6
# 347088.0        6
# 3101295.0       6
# 382652.0        5
# 14879.0         5

# %%
plt.figure(figsize=(12, 12))
plt.xticks(rotation=45)


valuecount[filt].plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50, 50))
plt.xticks(rotation=45)
plt.bar(valuecount.index, valuecount.values)
# Out:
# <BarContainer object of 635 artists>
